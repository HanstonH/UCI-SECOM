# %% [markdown]
# ## Exploring The Data

# %%
import pandas as pd

FILEPATH = r"archive\uci-secom.csv"
UCI_SECOM_dataset = pd.read_csv(FILEPATH)
UCI_SECOM_dataset
# Out:
#                      Time        0        1          2          3       4  \
# 0     2008-07-19 11:55:00  3030.93  2564.00  2187.7333  1411.1265  1.3602
# 1     2008-07-19 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294
# 2     2008-07-19 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102
# 3     2008-07-19 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204
# 4     2008-07-19 15:22:00  3032.24  2502.87  2233.3667  1326.5200  1.5334
# ...                   ...      ...      ...        ...        ...     ...
# 1562  2008-10-16 15:13:00  2899.41  2464.36  2179.7333  3085.3781  1.4843
# 1563  2008-10-16 20:49:00  3052.31  2522.55  2198.5667  1124.6595  0.8763
# 1564  2008-10-17 05:26:00  2978.81  2379.78  2206.3000  1110.4967  0.8236
# 1565  2008-10-17 06:01:00  2894.92  2532.01  2177.0333  1183.7287  1.5726
# 1566  2008-10-17 06:07:00  2944.92  2450.76  2195.4444  2914.1792  1.5978
#
#           5         6       7       8  ...       581     582     583     584  \
# ...

# %%
UCI_SECOM_dataset.value_counts("Pass/Fail")
# Out:
# Pass/Fail
# -1    1463
#  1     104
# Name: count, dtype: int64

# %%
# Since im deleting time, no need to convert string to number
# UCI_SECOM_dataset.dtypes.value_counts()

# %%
# import matplotlib.pyplot as plt

# UCI_SECOM_dataset.hist(bins=50, figsize=(20,15))
# plt.show()

# %% [markdown]
# ## Splitting The Dataset

# %%
# Since it's already sorted by time, we can separate it easily
# column_sum = len(UCI_SECOM_dataset.columns)

index_sum = len(UCI_SECOM_dataset)
split = round(index_sum * 0.8)
training_split = UCI_SECOM_dataset[:split]
testing_split = UCI_SECOM_dataset[split:]

# %%
training_split.value_counts("Pass/Fail")
# Out:
# Pass/Fail
# -1    1167
#  1      87
# Name: count, dtype: int64

# %% [markdown]
# ## Pipeline

# %%
training_data = training_split.drop(columns="Pass/Fail")
training_label = training_split["Pass/Fail"]

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class CustomTranformator(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        data = X.copy()
        data.drop(columns=["Time"], inplace=True)
        return data

# %%
# Problem 1: many missing values -> imputers
# Problem 2: Need to be standardized (data varies too large) -> std
# Problem 3: Time might cause temporal leakeage -> remove from data
# After this put PCA (later after using without to check accuracy)
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

pipeline = Pipeline([
    ('custom', CustomTranformator()),
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
    ('pca', PCA())
])
final_dataset = pipeline.fit_transform(training_data)

# %%
# PCA!
# columns = list(training_data.columns)
# columns.remove('Time')

final_dataset_dataframe = pd.DataFrame(
    final_dataset
)
final_dataset_dataframe
# Out:
#            0         1         2         3         4         5          6    \
# 0    -1.680284 -2.095135  3.279701 -2.059105 -1.963834 -1.550592   2.691773
# 1    -2.281144 -0.268489  2.351333 -1.555019 -2.583460 -0.565508   3.134543
# 2     0.856315 -1.118508  1.403522 -0.892967 -0.914171  1.885987   0.109128
# 3     1.863786 -4.533767  4.435949 -4.859907 -5.588165 -7.148467  -8.347313
# 4     1.533506 -2.370757  3.429716 -2.443270 -1.693298  1.818304  -7.302256
# ...        ...       ...       ...       ...       ...       ...        ...
# 1249  1.559021  3.659582 -1.627361  1.186056 -1.676532  6.810497   1.146897
# 1250  0.304290  2.542348 -3.528388  2.691257 -1.236288 -1.088409  -5.540596
# 1251 -0.769923  1.764115 -2.000270  2.108429 -1.031194  4.968919  -2.852413
# 1252  1.321503  2.452466 -4.327941  3.532730  0.981838 -2.852135 -10.326377
# 1253 -0.685712  0.605760 -0.906334  1.149478 -1.870685  4.825289  -2.362466
#
# ...

# %%
training_label.replace(-1,0, inplace=True)
training_label
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1249    0
# 1250    0
# 1251    0
# 1252    0
# 1253    0
# Name: Pass/Fail, Length: 1254, dtype: int64

# %% [markdown]
# ## Training Model

# %%
# Ensemble model afterwards
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

lr = LogisticRegression()
rf = RandomForestClassifier()
svc = SVC()
xgb = XGBClassifier()

# %%
from sklearn.model_selection import cross_val_score

# lr_scores = cross_val_score(lr, final_dataset_dataframe, training_label, scoring="accuracy")
# print("Scores: ", lr_scores)
# rf_scores = cross_val_score(rf, final_dataset_dataframe, training_label, scoring="accuracy")
# print("Scores: ", rf_scores)
# svc_scores = cross_val_score(svc, final_dataset_dataframe, training_label, scoring="accuracy")
# print("Scores: ", svc_scores)
# xgb_scores = cross_val_score(xgb, final_dataset_dataframe, training_label, scoring="accuracy")
# print("Scores: ", xgb_scores)

# Scores lr:  [0.49800797 0.73705179 0.84462151 0.87250996 0.9       ]
# Scores rf:  [0.8685259  0.92031873 0.92828685 0.92828685 0.932     ]
# Scores svc:  [0.93227092 0.93227092 0.92828685 0.92828685 0.932     ]

# After PCA
# Scores lr:  [0.5059761  0.73705179 0.84462151 0.87250996 0.904     ]
# Scores rf:  [0.93227092 0.93227092 0.92828685 0.92828685 0.932     ]
# Scores svc:  [0.93227092 0.93227092 0.92828685 0.92828685 0.932     ]
# Scores xgb: [0.93227092 0.93227092 0.92828685 0.92828685 0.932     ]

# %% [markdown]
# ## Grid Search

# %%
# Logistic Regression
import numpy as np
from sklearn.model_selection import GridSearchCV

lr_param_grid = {
    'l1_ratio': [0],
    'max_iter': [50, 100, 200],
    'C':  np.logspace(-4, 4, 20),
}

grid_search_lr = GridSearchCV(
    lr,
    lr_param_grid,
    cv=3,
    n_jobs=-1,
    scoring='accuracy'
)
TRAIN_NEW_MODEL = True
if TRAIN_NEW_MODEL:
    grid_search_lr.fit(final_dataset_dataframe, training_label)

# %%
import joblib
if TRAIN_NEW_MODEL:
    best_param = grid_search_lr.best_params_
    print(grid_search_lr.best_score_)
    print(best_param)
    joblib.dump(grid_search_lr.best_estimator_, "lr_best_estimator")
# 0.9306231075697211
# Out:
# 0.9306220095693781
# {'C': np.float64(0.0001), 'l1_ratio': 0, 'max_iter': 50}

# %%
# Random Forest
rf_param_grid = {
    "n_estimators": [100, 200],
    "max_depth": [None, 5, 10],
    "min_samples_split": [2, 5, 10]
}

grid_search_rf = GridSearchCV(
    rf,
    rf_param_grid,
    cv=3,
    n_jobs=-1,
    scoring='accuracy'
)
TRAIN_NEW_MODEL = True
if TRAIN_NEW_MODEL:
    grid_search_rf.fit(final_dataset_dataframe, training_label)

# %%
if TRAIN_NEW_MODEL:
    best_param = grid_search_rf.best_params_
    print(grid_search_rf.best_score_)
    print(best_param)
    joblib.dump(grid_search_rf.best_estimator_, "rf_best_estimator")
# 0.9306220095693781
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
# Out:
# 0.9306220095693781
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}

# %%
# svc
svc_param_grid = {
    "C": [0.1, 1, 10, 100],
    "gamma": ["scale", 0.1, 0.01, 0.001],
    "kernel": ["rbf"]
}
grid_search_svc = GridSearchCV(
    svc,
    svc_param_grid,
    cv=3,
    n_jobs=-1,
    scoring='accuracy'
)
TRAIN_NEW_MODEL = True
if TRAIN_NEW_MODEL:
    grid_search_svc.fit(final_dataset_dataframe, training_label)

# %%
if TRAIN_NEW_MODEL:
    best_param = grid_search_svc.best_params_
    print(grid_search_svc.best_score_)
    print(best_param)
    joblib.dump(grid_search_svc.best_estimator_, "svc_best_estimator")
# 0.9306220095693781
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
# Out:
# 0.9306220095693781
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}

# %% [markdown]
# ## Ensemble

# %%
# svc
xgb_param_grid = {
    "scale_pos_weight": [1, 5, 10],
    "n_estimators": [100, 200, 300]
}
grid_search_xgb = GridSearchCV(
    xgb,
    xgb_param_grid,
    cv=3,
    n_jobs=-1,
    scoring='accuracy'
)
TRAIN_NEW_MODEL = True
if TRAIN_NEW_MODEL:
    grid_search_xgb.fit(final_dataset_dataframe, training_label)

# %%
if TRAIN_NEW_MODEL:
    best_param = grid_search_xgb.best_params_
    print(grid_search_xgb.best_score_)
    print(best_param)
    joblib.dump(grid_search_xgb.best_estimator_, "xgb_best_estimator")
# 0.9298245614035089
# {'n_estimators': 100, 'scale_pos_weight': 5}
# Out:
# 0.9298245614035089
# {'n_estimators': 100, 'scale_pos_weight': 5}

# %%
from sklearn.ensemble import VotingClassifier

lr_best = joblib.load("lr_best_estimator")
rf_best = joblib.load("rf_best_estimator")
svc_best= joblib.load("svc_best_estimator")
xgb_best = joblib.load("xgb_best_estimator")

voting_clf = VotingClassifier(
    estimators=[('lr', lr_best), ('rf', rf_best), ('svc', svc_best), ('xgb', xgb_best)],
    voting='hard'
)
voting_clf.fit(final_dataset_dataframe, training_label)
# Out:
# VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=np.float64(0.0001),
#                                                  l1_ratio=0, max_iter=50)),
#                              ('rf', RandomForestClassifier()),
#                              ('svc', SVC(C=0.1)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eva...
#                                             feature_weights=None, gamma=None,
# ...

# %% [markdown]
# ## Testing

# %%
testing_split_data = testing_split.drop(columns="Pass/Fail")
testing_split_label = testing_split["Pass/Fail"]

testing_split_label.replace(-1,0, inplace=True)
testing_split_data_final = pipeline.transform(testing_split_data)

# %%
from sklearn.metrics import accuracy_score

for clf in (lr_best, rf_best, svc_best, xgb_best, voting_clf):
    y_pred = clf.predict(testing_split_data_final)
    print(clf.__class__.__name__, accuracy_score(testing_split_label, y_pred))
# Out:
# LogisticRegression 0.9329073482428115
# RandomForestClassifier 0.7635782747603834
# SVC 0.9456869009584664
# XGBClassifier 0.9456869009584664
# VotingClassifier 0.9456869009584664
